# %% [markdown]
# ## gravitación

# %%
6.67*10**(-11)==G 
print (G)
# Out:
# 6.67e-11

# %%
m1= float(input("m1: "))

# %%
m2= float(input("m2:"))
# Out:
# m2: 3

# %%
r= float(input("r: "))
# Out:
# r:  20

# %%
Gf = G*(m1*m2/r**2)

# %%
print ('la fuerza gravitacional es'),Gf
# Out:
# la fuerza gravitacional es
# (None, 2.50125e-12)
